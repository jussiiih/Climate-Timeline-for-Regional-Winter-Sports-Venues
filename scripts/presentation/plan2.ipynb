# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cloud data just numbers

# %% [markdown]
# ### See what values there is

# %%
# HIMOS
himos_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\himos.csv")
unique_values = himos_df['Cloud cover [1/8]'].unique()

# KOLI
koli_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\koli.csv")

# LEVI
levi_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\levi.csv")

# MESSILA
messila_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\messila.csv")

# PEURAMAA
peuramaa_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\peuramaa.csv")

# PYHA
pyha_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\pyha.csv")

# RUKA
ruka_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\ruka.csv")

# SAARISELKA
saariselka_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\saariselka.csv")

# TAHKO
tahko_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\tahko.csv")

# VUOKATTI
vuokatti_df = pd.read_csv("C:\\Users\\otso\\Dropbox\\Brights Laptop\\projects\\Miniproject2\\repo\\Miniproject2-Group3\\combined data\\vuokatti.csv")


# print(unique_values)
peuramaa_df
# Out:
#         Cloud cover [1/8]        Date  Snow depth [cm]  Unnamed: 0  \
# 0     Mostly cloudy (7/8)  2004-01-01              NaN           0
# 1             Clear (0/8)  2004-01-02              0.0           1
# 2             Clear (0/8)  2004-01-03              0.0           2
# 3             Clear (1/8)  2004-01-04              0.0           3
# 4            Cloudy (8/8)  2004-01-05              NaN           4
# ...                   ...         ...              ...         ...
# 7301         Cloudy (8/8)  2023-12-28             21.0        7301
# 7302         Cloudy (8/8)  2023-12-29             20.0        7302
# 7303         Cloudy (8/8)  2023-12-30             29.0        7303
# 7304         Cloudy (8/8)  2023-12-31             28.0        7304
# 7305          Clear (0/8)  2024-01-01             27.0        7305
#
#       Average temperature [°C]   latitude  longitude  Average radiation
# 0                         -7.2  60.102686  24.464341          63.400000
# 1                        -11.9  60.102686  24.464341          65.666667
# 2                        -10.2  60.102686  24.464341          54.566667
# 3                         -4.4  60.102686  24.464341           4.500000
# 4                         -3.2  60.102686  24.464341           3.466667
# ...                        ...        ...        ...                ...
# 7301                      -0.7  60.102686  24.464341           6.931169
# 7302                       0.5  60.102686  24.464341           3.621587
# 7303                      -3.0  60.102686  24.464341           0.744444
# 7304                     -13.3  60.102686  24.464341           3.164127
# 7305                     -15.8  60.102686  24.464341           7.247213
#
# [7306 rows x 8 columns]

# %% [markdown]
# ### Combine to 5 training sets and one test set and 4 future predictions

# %%
training_df = pd.concat([saariselka_df, pyha_df, himos_df, peuramaa_df])
test_df = vuokatti_df
prediction_df = pd.concat([levi_df, ruka_df, koli_df, tahko_df, messila_df])

# %%
training_df
# Out:
#         Cloud cover [1/8]        Date Snow depth [cm]  Unnamed: 0  \
# 0             Clear (0/8)  2004-01-01              40         0.0
# 1     Mostly cloudy (7/8)  2004-01-02              40         1.0
# 2     Mostly cloudy (7/8)  2004-01-03              40         2.0
# 3            Cloudy (8/8)  2004-01-04              40         3.0
# 4            Cloudy (8/8)  2004-01-05              40         4.0
# ...                   ...         ...             ...         ...
# 7301         Cloudy (8/8)  2023-12-28            21.0      7301.0
# 7302         Cloudy (8/8)  2023-12-29            20.0      7302.0
# 7303         Cloudy (8/8)  2023-12-30            29.0      7303.0
# 7304         Cloudy (8/8)  2023-12-31            28.0      7304.0
# 7305          Clear (0/8)  2024-01-01            27.0      7305.0
#
#      Average temperature [°C]   latitude  longitude  Average radiation
# 0                       -21.8  68.425135  27.449662          63.400000
# 1                       -22.2  68.425135  27.449662          65.666667
# 2                       -20.6  68.425135  27.449662          54.566667
# 3                       -16.1  68.425135  27.449662           4.500000
# 4                       -15.5  68.425135  27.449662           3.466667
# ...                       ...        ...        ...                ...
# 7301                     -0.7  60.102686  24.464341           6.931169
# 7302                      0.5  60.102686  24.464341           3.621587
# 7303                     -3.0  60.102686  24.464341           0.744444
# 7304                    -13.3  60.102686  24.464341           3.164127
# 7305                    -15.8  60.102686  24.464341           7.247213
#
# [29224 rows x 8 columns]

# %%
prediction_df
# Out:
#         Cloud cover [1/8]        Date Snow depth [cm]  Unnamed: 0  \
# 0             Clear (0/8)  2004-01-01              39         0.0
# 1     Mostly cloudy (7/8)  2004-01-02              39         1.0
# 2     Mostly cloudy (7/8)  2004-01-03              39         2.0
# 3            Cloudy (8/8)  2004-01-04              40         3.0
# 4            Cloudy (8/8)  2004-01-05              40         4.0
# ...                   ...         ...             ...         ...
# 7302         Cloudy (8/8)  2023-12-28              27      1952.0
# 7303         Cloudy (8/8)  2023-12-29              28      1953.0
# 7304         Cloudy (8/8)  2023-12-30              32      1954.0
# 7305  Mostly cloudy (6/8)  2023-12-31              30      1955.0
# 7306  Mostly cloudy (6/8)  2024-01-01              30      1956.0
#
#      Average temperature [°C]   latitude  longitude  Average radiation
# 0                       -27.3  67.785461  24.856284          63.400000
# 1                         -30  67.785461  24.856284          65.666667
# 2                       -20.5  67.785461  24.856284          54.566667
# 3                       -15.2  67.785461  24.856284           4.500000
# 4                       -19.3  67.785461  24.856284           3.466667
# ...                       ...        ...        ...                ...
# 7302                     -4.1  61.013791  25.558544           6.931169
# 7303                     -3.3  61.013791  25.558544           3.621587
# 7304                     -6.5  61.013791  25.558544           0.744444
# 7305                    -14.7  61.013791  25.558544           3.164127
# 7306                    -18.9  61.013791  25.558544           7.247213
#
# [36531 rows x 8 columns]

# %%
test_df
# Out:
#        Cloud cover [1/8]        Date Snow depth [cm]  Unnamed: 0  \
# 0            Clear (0/8)  2004-01-01              31         0.0
# 1            Clear (1/8)  2004-01-02              31         1.0
# 2           Cloudy (8/8)  2004-01-03              31         2.0
# 3           Cloudy (8/8)  2004-01-04              32         3.0
# 4           Cloudy (8/8)  2004-01-05              32         4.0
# ...                  ...         ...             ...         ...
# 7301        Cloudy (8/8)  2023-12-28              44      7282.0
# 7302        Cloudy (8/8)  2023-12-29              44      7283.0
# 7303  Mostly clear (2/8)  2023-12-30              43      7284.0
# 7304         Clear (0/8)  2023-12-31              43      7285.0
# 7305         Clear (0/8)  2024-01-01              42      7286.0
#
#      Average temperature [°C]   latitude  longitude  Average radiation
# 0                       -24.9  64.139453  28.287481          63.400000
# 1                       -19.2  64.139453  28.287481          65.666667
# 2                         -13  64.139453  28.287481          54.566667
# 3                       -13.9  64.139453  28.287481           4.500000
# 4                       -13.5  64.139453  28.287481           3.466667
# ...                       ...        ...        ...                ...
# 7301                     -7.2  64.139453  28.287481           6.931169
# 7302                      -10  64.139453  28.287481           3.621587
# 7303                    -12.6  64.139453  28.287481           0.744444
# 7304                    -12.9  64.139453  28.287481           3.164127
# 7305                    -25.8  64.139453  28.287481           7.247213
#
# [7306 rows x 8 columns]

# %% [markdown]
# ## Sort dataframe by date

# %%
# TEST
test_df.sort_values(by='Date', inplace=True)
# PREDICTION
prediction_df.sort_values(by='Date', inplace=True)
# Train
training_df.sort_values(by='Date', inplace=True)

training_df
# Out:
#         Cloud cover [1/8]        Date Snow depth [cm]  Unnamed: 0  \
# 0             Clear (0/8)  2004-01-01              40         0.0
# 0     Mostly cloudy (7/8)  2004-01-01             NaN         0.0
# 0            Cloudy (8/8)  2004-01-01              15         0.0
# 0            Cloudy (8/8)  2004-01-01            25.0         0.0
# 1             Clear (0/8)  2004-01-02             0.0         1.0
# ...                   ...         ...             ...         ...
# 7304  Partly cloudy (4/8)  2023-12-31              58      7304.0
# 7305          Clear (0/8)  2024-01-01            56.0      7305.0
# 7305         Cloudy (8/8)  2024-01-01              58      7305.0
# 7305   Mostly clear (2/8)  2024-01-01              27      7281.0
# 7305          Clear (0/8)  2024-01-01            27.0      7305.0
#
#      Average temperature [°C]   latitude  longitude  Average radiation
# 0                       -21.8  68.425135  27.449662          63.400000
# 0                        -7.2  60.102686  24.464341          63.400000
# 0                       -17.2  61.879612  25.299437          63.400000
# 0                       -29.6  67.014257  27.149530          63.400000
# 1                       -11.9  60.102686  24.464341          65.666667
# ...                       ...        ...        ...                ...
# 7304                    -12.9  68.425135  27.449662           3.164127
# 7305                    -23.9  67.014257  27.149530           7.247213
# 7305                    -17.2  68.425135  27.449662           7.247213
# 7305                    -22.9  61.879612  25.299437           7.247213
# 7305                    -15.8  60.102686  24.464341           7.247213
#
# [29224 rows x 8 columns]

# %% [markdown]
# ### Remove duplicate rows

# %%
# TRAINING DF
duplicates_train = training_df.duplicated(subset='Date')
training_df[duplicates_train]

# PREDICTION DF
duplicates_pred = prediction_df.duplicated(subset='Date')
prediction_df[duplicates_pred]

# TESTING DF
duplicates_test = test_df.duplicated(subset='Date')
test_df[duplicates_test]
# Out:
# Empty DataFrame
# Columns: [Cloud cover [1/8], Date, Snow depth [cm], Unnamed: 0, Average temperature [°C], latitude, longitude, Average radiation]
# Index: []

# %%
# Start removing duplicate rows from datasets

training_df.drop_duplicates(inplace=True, ignore_index=True)

prediction_df.drop_duplicates(inplace=True, ignore_index=True)

test_df.drop_duplicates(inplace=True, ignore_index=True)

# %%
test_df
# Out:
#        Cloud cover [1/8]        Date Snow depth [cm]  Unnamed: 0  \
# 0            Clear (0/8)  2004-01-01              31         0.0
# 1            Clear (1/8)  2004-01-02              31         1.0
# 2           Cloudy (8/8)  2004-01-03              31         2.0
# 3           Cloudy (8/8)  2004-01-04              32         3.0
# 4           Cloudy (8/8)  2004-01-05              32         4.0
# ...                  ...         ...             ...         ...
# 7301        Cloudy (8/8)  2023-12-28              44      7282.0
# 7302        Cloudy (8/8)  2023-12-29              44      7283.0
# 7303  Mostly clear (2/8)  2023-12-30              43      7284.0
# 7304         Clear (0/8)  2023-12-31              43      7285.0
# 7305         Clear (0/8)  2024-01-01              42      7286.0
#
#      Average temperature [°C]   latitude  longitude  Average radiation
# 0                       -24.9  64.139453  28.287481          63.400000
# 1                       -19.2  64.139453  28.287481          65.666667
# 2                         -13  64.139453  28.287481          54.566667
# 3                       -13.9  64.139453  28.287481           4.500000
# 4                       -13.5  64.139453  28.287481           3.466667
# ...                       ...        ...        ...                ...
# 7301                     -7.2  64.139453  28.287481           6.931169
# 7302                      -10  64.139453  28.287481           3.621587
# 7303                    -12.6  64.139453  28.287481           0.744444
# 7304                    -12.9  64.139453  28.287481           3.164127
# 7305                    -25.8  64.139453  28.287481           7.247213
#
# [7306 rows x 8 columns]

# %% [markdown]
# ## Clean up cloud data that there is only numbers left

# %%
test_df['Cloud cover [1/8]'] = test_df['Cloud cover [1/8]'].str.extract(r'\((\d+)/')
prediction_df['Cloud cover [1/8]'] = prediction_df['Cloud cover [1/8]'].str.extract(r'\((\d+)/')
training_df['Cloud cover [1/8]'] = training_df['Cloud cover [1/8]'].str.extract(r'\((\d+)/')

# %%
training_df
# Out:
#       Cloud cover [1/8]        Date Snow depth [cm]  Unnamed: 0  \
# 0                     0  2004-01-01              40         0.0
# 1                     7  2004-01-01             NaN         0.0
# 2                     8  2004-01-01              15         0.0
# 3                     8  2004-01-01            25.0         0.0
# 4                     0  2004-01-02             0.0         1.0
# ...                 ...         ...             ...         ...
# 29219                 4  2023-12-31              58      7304.0
# 29220                 0  2024-01-01            56.0      7305.0
# 29221                 8  2024-01-01              58      7305.0
# 29222                 2  2024-01-01              27      7281.0
# 29223                 0  2024-01-01            27.0      7305.0
#
#       Average temperature [°C]   latitude  longitude  Average radiation
# 0                        -21.8  68.425135  27.449662          63.400000
# 1                         -7.2  60.102686  24.464341          63.400000
# 2                        -17.2  61.879612  25.299437          63.400000
# 3                        -29.6  67.014257  27.149530          63.400000
# 4                        -11.9  60.102686  24.464341          65.666667
# ...                        ...        ...        ...                ...
# 29219                    -12.9  68.425135  27.449662           3.164127
# 29220                    -23.9  67.014257  27.149530           7.247213
# 29221                    -17.2  68.425135  27.449662           7.247213
# 29222                    -22.9  61.879612  25.299437           7.247213
# 29223                    -15.8  60.102686  24.464341           7.247213
#
# [29224 rows x 8 columns]

# %% [markdown]
# ### Drop unnamed column

# %%
test_df = test_df.drop('Unnamed: 0',axis=1)
training_df = training_df.drop('Unnamed: 0',axis=1)
prediction_df = prediction_df.drop('Unnamed: 0',axis=1)

# %% [markdown]
# ### Remove duplicate rows
# ![](duplicates.jpg)

# %% [markdown]
# ### Decide and convert columns to wanted datatypes

# %%
# TEST
print(type(test_df['Average temperature [°C]'][0]))
print(type(test_df['Date'][0]))
# Make new datecolumn from string date with instructions from https://mohammadimranhasan.com/linear-regression-of-time-series-data-with-pandas-library-in-python/ basicly index2
test_df['Date_float'] = np.array(pd.to_datetime(test_df['Date'].dropna()).index.values, dtype=float)
# Make temperature to float
test_df['Temp_float'] = pd.to_numeric(test_df['Average temperature [°C]'], errors='coerce')
# Make snow depth to float
test_df['Snow depth_float'] = pd.to_numeric(test_df['Snow depth [cm]'], errors='coerce')
test_df['Cloud cover [1/8]'] = pd.to_numeric(test_df['Cloud cover [1/8]'], errors='coerce')

# TRAIN
print(type(training_df['Average temperature [°C]'][0]))
print(type(training_df['Date'][0]))
# Make new datecolumn from string date with instructions from https://mohammadimranhasan.com/linear-regression-of-time-series-data-with-pandas-library-in-python/ basicly index2
training_df['Date_float'] = np.array(pd.to_datetime(training_df['Date'].dropna()).index.values, dtype=float)
# Make temperature to float
training_df['Temp_float'] = pd.to_numeric(training_df['Average temperature [°C]'], errors='coerce')
# Make snow depth to float
training_df['Snow depth_float'] = pd.to_numeric(training_df['Snow depth [cm]'], errors='coerce')
training_df['Cloud cover [1/8]'] = pd.to_numeric(training_df['Cloud cover [1/8]'], errors='coerce')

# PREDICTION
print(type(prediction_df['Average temperature [°C]'][0]))
print(type(prediction_df['Date'][0]))
# Make new datecolumn from string date with instructions from https://mohammadimranhasan.com/linear-regression-of-time-series-data-with-pandas-library-in-python/ basicly index2
prediction_df['Date_float'] = np.array(pd.to_datetime(prediction_df['Date'].dropna()).index.values, dtype=float)
# Make temperature to float
prediction_df['Temp_float'] = pd.to_numeric(prediction_df['Average temperature [°C]'], errors='coerce')
# Make snow depth to float
prediction_df['Snow depth_float'] = pd.to_numeric(prediction_df['Snow depth [cm]'], errors='coerce')
prediction_df['Cloud cover [1/8]'] = pd.to_numeric(prediction_df['Cloud cover [1/8]'], errors='coerce')
# Out:
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# # Machine Learning Part

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Split Datasets into
#     *4 venue sets for training
#     *1 set for testing
#     *5 for predictions in future data points

# %% [markdown]
# ### 1. Choose models
#     * Several trained regression models
#     * Nice if other models also, clustering, classification

# %%
training_df
# Out:
#        Cloud cover [1/8]        Date Snow depth [cm] Average temperature [°C]  \
# 0                    0.0  2004-01-01              40                    -21.8
# 1                    7.0  2004-01-01             NaN                     -7.2
# 2                    8.0  2004-01-01              15                    -17.2
# 3                    8.0  2004-01-01            25.0                    -29.6
# 4                    0.0  2004-01-02             0.0                    -11.9
# ...                  ...         ...             ...                      ...
# 29219                4.0  2023-12-31              58                    -12.9
# 29220                0.0  2024-01-01            56.0                    -23.9
# 29221                8.0  2024-01-01              58                    -17.2
# 29222                2.0  2024-01-01              27                    -22.9
# 29223                0.0  2024-01-01            27.0                    -15.8
#
#         latitude  longitude  Average radiation  Date_float  Temp_float  \
# 0      68.425135  27.449662          63.400000         0.0       -21.8
# 1      60.102686  24.464341          63.400000         1.0        -7.2
# 2      61.879612  25.299437          63.400000         2.0       -17.2
# 3      67.014257  27.149530          63.400000         3.0       -29.6
# 4      60.102686  24.464341          65.666667         4.0       -11.9
# ...          ...        ...                ...         ...         ...
# 29219  68.425135  27.449662           3.164127     29219.0       -12.9
# 29220  67.014257  27.149530           7.247213     29220.0       -23.9
# 29221  68.425135  27.449662           7.247213     29221.0       -17.2
# 29222  61.879612  25.299437           7.247213     29222.0       -22.9
# 29223  60.102686  24.464341           7.247213     29223.0       -15.8
#
#        Snow depth_float
# 0                  40.0
# 1                  27.5
# 2                  15.0
# 3                  25.0
# 4                   0.0
# ...                 ...
# 29219              58.0
# 29220              56.0
# 29221              58.0
# 29222              27.0
# 29223              27.0
#
# [29224 rows x 10 columns]

# %%
test_df
# Out:
#       Cloud cover [1/8]        Date Snow depth [cm] Average temperature [°C]  \
# 0                   0.0  2004-01-01              31                    -24.9
# 1                   1.0  2004-01-02              31                    -19.2
# 2                   8.0  2004-01-03              31                      -13
# 3                   8.0  2004-01-04              32                    -13.9
# 4                   8.0  2004-01-05              32                    -13.5
# ...                 ...         ...             ...                      ...
# 7301                8.0  2023-12-28              44                     -7.2
# 7302                8.0  2023-12-29              44                      -10
# 7303                2.0  2023-12-30              43                    -12.6
# 7304                0.0  2023-12-31              43                    -12.9
# 7305                0.0  2024-01-01              42                    -25.8
#
#        latitude  longitude  Average radiation  Date_float  Temp_float  \
# 0     64.139453  28.287481          63.400000         0.0       -24.9
# 1     64.139453  28.287481          65.666667         1.0       -19.2
# 2     64.139453  28.287481          54.566667         2.0       -13.0
# 3     64.139453  28.287481           4.500000         3.0       -13.9
# 4     64.139453  28.287481           3.466667         4.0       -13.5
# ...         ...        ...                ...         ...         ...
# 7301  64.139453  28.287481           6.931169      7301.0        -7.2
# 7302  64.139453  28.287481           3.621587      7302.0       -10.0
# 7303  64.139453  28.287481           0.744444      7303.0       -12.6
# 7304  64.139453  28.287481           3.164127      7304.0       -12.9
# 7305  64.139453  28.287481           7.247213      7305.0       -25.8
#
#       Snow depth_float
# 0                 31.0
# 1                 31.0
# 2                 31.0
# 3                 32.0
# 4                 32.0
# ...                ...
# 7301              44.0
# 7302              44.0
# 7303              43.0
# 7304              43.0
# 7305              42.0
#
# [7306 rows x 10 columns]

# %%
prediction_df
# Out:
#        Cloud cover [1/8]        Date Snow depth [cm] Average temperature [°C]  \
# 0                    0.0  2004-01-01              39                    -27.3
# 1                    7.0  2004-01-01              32                    -24.5
# 2                    8.0  2004-01-01              10                    -10.4
# 3                    8.0  2004-01-01              34                    -14.5
# 4                    0.0  2004-01-01              34                    -24.4
# ...                  ...         ...             ...                      ...
# 36526                5.0  2024-01-01              34                    -17.5
# 36527                7.0  2024-01-01              58                    -20.7
# 36528                0.0  2024-01-01              61                    -23.2
# 36529                0.0  2024-01-01              51                    -25.8
# 36530                6.0  2024-01-01              30                    -18.9
#
#         latitude  longitude  Average radiation  Date_float  Temp_float  \
# 0      67.785461  24.856284          63.400000         0.0       -27.3
# 1      63.099198  29.819182          63.400000         1.0       -24.5
# 2      61.013791  25.558544          63.400000         2.0       -10.4
# 3      66.165756  29.152157          63.400000         3.0       -14.5
# 4      63.289114  28.040137          63.400000         4.0       -24.4
# ...          ...        ...                ...         ...         ...
# 36526  66.165756  29.152157           7.247213     36526.0       -17.5
# 36527  67.785461  24.856284           7.247213     36527.0       -20.7
# 36528  63.289114  28.040137           7.247213     36528.0       -23.2
# 36529  63.099198  29.819182           7.247213     36529.0       -25.8
# 36530  61.013791  25.558544           7.247213     36530.0       -18.9
#
#        Snow depth_float
# 0                  39.0
# 1                  32.0
# 2                  10.0
# 3                  34.0
# 4                  34.0
# ...                 ...
# 36526              34.0
# 36527              58.0
# 36528              61.0
# 36529              51.0
# 36530              30.0
#
# [36531 rows x 10 columns]

# %% [markdown]
# ### Decide what to do with cloud coverage NaN values, Now we drop the drows
#     1.) fillna
#     2.) dropna
#     3.) ffill
#     4.) bfill

# %%
def fill_na(dataframe, column):
    #fillna_list = np.array(['Cloud cover [1/8]', 'Snow depth_float', 'Temp_float'])
    filled_forward = dataframe[column].fillna(method='ffill')
 
    # # Backward fill NaN values in column 'A'
    filled_backward = dataframe[column].fillna(method='bfill')
    
    # # Handle first and last value separately
    first_value = dataframe[column].iloc[0]
    last_value = dataframe[column].iloc[-1]
    
    # # Calculate the average of forward filled and backward filled values
    average_values = (filled_forward + filled_backward) / 2
    
    # # Replace NaN values in column 'A' with the calculated average
    dataframe[column] = dataframe[column].combine_first(average_values)
    
    # # Handle first and last value
    if pd.isna(first_value):
        dataframe[column].iloc[0] = filled_backward.iloc[0]
    if pd.isna(last_value):
        dataframe[column].iloc[-1] = filled_forward.iloc[-1]

fill_na(test_df, 'Cloud cover [1/8]')
fill_na(test_df, 'Snow depth_float')
fill_na(test_df, 'Temp_float')

fill_na(training_df, 'Cloud cover [1/8]')
fill_na(training_df, 'Snow depth_float')
fill_na(training_df, 'Temp_float')

fill_na(prediction_df, 'Cloud cover [1/8]')
fill_na(prediction_df, 'Snow depth_float')
fill_na(prediction_df, 'Temp_float')
# Out:
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = dataframe[column].fillna(method='ffill')
# C:\Users\otso\AppData\Local\Temp\ipykernel_19080\2334615683.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_backward = dataframe[column].fillna(method='bfill')

# %% [markdown]
# ### Drop NaN values

# %%
# # HIMOS
# filt = himos_df['Cloud cover [1/8]'].isna() == True
# himos_df.dropna(how='any', axis=0, inplace=True)

# #KOLI
# filt = koli_df['Cloud cover [1/8]'].isna() == True
# koli_df.dropna(how='any', axis=0, inplace=True)

# %% [markdown]
# ## Use Cloud cover, latitude, radiation, date, temp as Independent Variables (Features)
# ## Use now depth as Dependent Variables (Target Variable):

# %%
training_df.tail(1)
# Out:
#        Cloud cover [1/8]        Date Snow depth [cm] Average temperature [°C]  \
# 29223                0.0  2024-01-01            27.0                    -15.8
#
#         latitude  longitude  Average radiation  Date_float  Temp_float  \
# 29223  60.102686  24.464341           7.247213     29223.0       -15.8
#
#        Snow depth_float
# 29223              27.0

# %%
# Choose columns from combined training dataset for training and we predict snow
# training_df
# training_df.iloc[:,[0,4,6,7,8]]
X_train = training_df.iloc[:,[0,4,6,7,8]]
y_train = training_df.iloc[:,[9]]

# %%
y_train
# Out:
#        Snow depth_float
# 0                  40.0
# 1                  27.5
# 2                  15.0
# 3                  25.0
# 4                   0.0
# ...                 ...
# 29219              58.0
# 29220              56.0
# 29221              58.0
# 29222              27.0
# 29223              27.0
#
# [29224 rows x 1 columns]

# %%
# Choose columns from combined test dataset for testing
test_df
X_test = test_df.iloc[:,[0,4,6,7,8]]
y_test = test_df.iloc[:,[9]]

# %%
X_test
# Out:
#       Cloud cover [1/8]   latitude  Average radiation  Date_float  Temp_float
# 0                   0.0  64.139453          63.400000         0.0       -24.9
# 1                   1.0  64.139453          65.666667         1.0       -19.2
# 2                   8.0  64.139453          54.566667         2.0       -13.0
# 3                   8.0  64.139453           4.500000         3.0       -13.9
# 4                   8.0  64.139453           3.466667         4.0       -13.5
# ...                 ...        ...                ...         ...         ...
# 7301                8.0  64.139453           6.931169      7301.0        -7.2
# 7302                8.0  64.139453           3.621587      7302.0       -10.0
# 7303                2.0  64.139453           0.744444      7303.0       -12.6
# 7304                0.0  64.139453           3.164127      7304.0       -12.9
# 7305                0.0  64.139453           7.247213      7305.0       -25.8
#
# [7306 rows x 5 columns]

# %% [markdown]
# ## Different models

# %%
# First degree regression model
model = LinearRegression()
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
# Second degree regression model
poly = PolynomialFeatures(degree=2, include_bias=False)

model_2d = LinearRegression()

# Transform to 2D array
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)
model_2d.fit(X_train_poly, y_train)

y_predicted_train = model_2d.predict(X_train_poly)
y_predicted_test = model_2d.predict(X_test_poly)

# Evaluating the model
train_rmse = np.sqrt(mean_squared_error(y_train, y_predicted_train))
test_rmse = np.sqrt(mean_squared_error(y_test, y_predicted_test))

print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# Train RMSE: 17.2642335125077
# Test RMSE: 16.45199841114083

# %% [markdown]
# ### 2. Train models

# %%
X_train.shape, y_test.shape
# Out:
# ((29224, 5), (7306, 1))

# %%
y_test
# Out:
#       Snow depth_float
# 0                 31.0
# 1                 31.0
# 2                 31.0
# 3                 32.0
# 4                 32.0
# ...                ...
# 7301              44.0
# 7302              44.0
# 7303              43.0
# 7304              43.0
# 7305              42.0
#
# [7306 rows x 1 columns]

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 2.5 Test model accuracy and values

# %%
# Test model with koli data
y_preds = model.predict(X_test)
# y_preds2 = model.predict(X_train)

# # Evaluating the model
# train_rmse = np.sqrt(mean_squared_error(y_train, y_preds2))
# test_rmse = np.sqrt(mean_squared_error(y_test, y_preds))

# print("Train RMSE:", train_rmse)
# print("Test RMSE:", test_rmse)
y_preds
# Out:
# array([[57.98973648],
#        [48.56779004],
#        [38.72682089],
#        ...,
#        [35.86627175],
#        [36.14871545],
#        [58.22125589]])

# %%
y_test
# Out:
#       Snow depth_float
# 0                 31.0
# 1                 31.0
# 2                 31.0
# 3                 32.0
# 4                 32.0
# ...                ...
# 7301              44.0
# 7302              44.0
# 7303              43.0
# 7304              43.0
# 7305              42.0
#
# [7306 rows x 1 columns]

# %%
y_preds
# Out:
# array([[40.46605665],
#        [38.81371275],
#        [25.97876961],
#        ...,
#        [27.76103992],
#        [22.72425095],
#        [36.36272223]])

# %% [markdown]
# ### 1D model against real values

# %%
y_preds
# Out:
# array([[57.98973648],
#        [48.56779004],
#        [38.72682089],
#        ...,
#        [35.86627175],
#        [36.14871545],
#        [58.22125589]])

# %%
fig, ax = plt.subplots(figsize=(30,10))
 
# %matplotlib inline
ax.plot(test_df['Date'], y_test, marker='o', ls='', alpha=0.2, label='Actual snow depth')
ax.plot(test_df['Date'], y_preds, marker='o', ls='', c='red', alpha=0.2, label='Predicted snow depth')
 
ax.set(title='First model trained',xlabel='Date', ylabel='Snow depth (cm)')
ax.legend()
plt.show()

# %% [markdown]
# ## 2nd degree model against real values

# %%
fig, ax = plt.subplots(figsize=(30,10))
 
# %matplotlib inline
ax.plot(test_df['Date'], y_test, marker='o', ls='', alpha=0.2, label='Actual snow depth')
ax.plot(test_df['Date'], y_predicted_test, marker='o', ls='', c='red', alpha=0.2, label='Predicted snow depth')
 
ax.set(title='First model trained',xlabel='Date', ylabel='Snow depth (cm)')
ax.legend()
plt.show()

# %% [markdown]
# ### 3. Save models

# %% [markdown]
# ### 4. Predict

# %% [markdown]
# ### 5. Estimate accuray

# %% [markdown]
# ### 6. Repeat

# %% [markdown]
# # Visualizations
